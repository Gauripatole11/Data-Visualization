# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
df = sns.load_dataset('titanic')
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
import seaborn as sns
import pandas as pd

# Sample data (replace with your actual data)
data = {'survived': [0,1,1,0],
        'pclass': [1,2,3,None],
        'sex': ['male', 'female', 'female', 'male'],
        'age': [20,None,30,22],
        'sibsp': [1,1,0,None],
        'parch': [0,0,None,1],
        'fare': [7.25, None, 8.05, 30.5],
        'embarked': ['S','C',None,'S']}
df = pd.DataFrame(data)

# Count missing values
missing_values = df.isnull().sum()

# Create a bar chart with Seaborn
sns.barplot(x=missing_values.index, y=missing_values)

# Customize the chart
plt.xlabel('Column Name')
plt.ylabel('Number of Missing Values')
plt.title('Missing Values Distribution in Titanic Dataset')
plt.show()

# %%
import seaborn as sns

# Load the Titanic dataset from Seaborn
df = sns.load_dataset('titanic')

# Print the first few rows of the dataset to verify the loading
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming df is your DataFrame loaded with the Titanic data
# plt.figure(figsize=(6, 4))
# sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
# plt.xticks(rotation=90)  # Rotate x-axis labels
# plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame loaded with the Titanic data
plt.figure(figsize=(6, 4))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.xticks(rotation=90)  # Rotate x-axis labels
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame loaded with the Titanic data
plt.figure(figsize=(6, 4))
sns.histplot(df['fare'], bins=20, color='lightblue')
plt.xlabel('fare ')
plt.ylabel('Frequency')
plt.title('fare distribution with hist')
plt.show()
# Out:
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame loaded with the Titanic data (ensure it's loaded)
plt.figure(figsize=(6, 4))

# Create the histogram for the 'fare' column with 20 bins and a lightblue color
sns.histplot(df['age'], bins=20, color='lightblue')

# Customize labels and title
plt.xlabel('age')  # Correct typo (remove extra space after 'fare')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
# Out:
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame loaded with the Titanic data
plt.figure(figsize=(6, 4))
sns.histplot(df['age'], bins=range(0, 81, 10), color='deepskyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution with Hist')
plt.show()
# Out:
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame loaded with the Titanic data
plt.figure(figsize=(6, 4))
sns.countplot(x='survived', data=df, palette='deep')  # Use deep blue color palette
plt.xlabel('survived')
plt.ylabel('count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset directly using seaborn
df = sns.load_dataset("titanic")

# Plotting the countplot
plt.figure(figsize=(6, 4))
sns.countplot(x='pclass', data=df, palette='deep')  # Ensure correct variable name
plt.xlabel('pclass')
plt.ylabel('count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame loaded with the Titanic data
plt.figure(figsize=(6, 4))
plt.xlim(-100, max(df['fare'])+50)  
plt.yticks([0, 20, 40, 60, 80])
sns.scatterplot(x='fare', y='age', data=df, color='blue', alpha=0.7)
plt.xlabel('fare')
plt.ylabel('age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Plotting
plt.figure(figsize=(6, 4))
sns.histplot(titanic['fare'], bins=20, color='red', kde=False)
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Fare Distribution with Histogram')
plt.grid(True)
plt.show()
# Out:
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Plotting
plt.figure(figsize=(6, 4))
sns.boxplot(x='class', y='age', data=titanic, palette='Set2')
plt.xlabel('class')
plt.ylabel('age')
plt.grid(True)
plt.show()
# Out:
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Select desired features (replace with your choices)
feature1 = 'Age'
feature2 = 'Fare'

# Create the scatter plot
sns.scatterplot(
    x=feature1,
    y=feature2,
    hue="sex",  # Optional: Add color-coding by 'sex'
    style="embarked",  # Optional: Add shape-coding by 'embarked'
    data=titanic
)

# Customize the plot (optional)
plt.xlabel(feature1)
plt.ylabel(feature2)
plt.title('Scatter Plot of Titanic Data')
plt.grid(True)  # Add grid lines for better readability
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33940\358897232.py in <module>
#      10
#      11 # Create the scatter plot
# ---> 12 sns.scatterplot(
#      13     x=feature1,
#      14     y=feature2,
#
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# c:\My Softwares\AnacondaPythonWF\envs\DataScience\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Plotting
plt.figure(figsize=(6, 4))
sns.countplot(x='sex', data=titanic, palette=['lightblue', 'lightgreen'])
plt.xlabel('sex')
plt.ylabel('count')
plt.grid()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from seaborn
titanic = sns.load_dataset("titanic")

# Calculate the correlation matrix
correlation = titanic.corr()

# Create the heatmap with coolwarm colormap
heatmap = sns.heatmap(correlation, cmap="coolwarm", annot=False, fmt=".5f", linewidths=0.0)

# Rotate x-axis labels
plt.xticks(rotation= 360)  # Correct indentation for xaxis rotation

# Customize the heatmap with a title 
heatmap.set_title('titanic.corr()')  # Add title

plt.show()

# %%
import seaborn as sns
import pandas as pd

# Assuming you have your data in a pandas dataframe called df
g = sns.FacetGrid(df, hue="sex", col="sex")
g.map(sns.histplot, "age", bins=10, edgecolor="grey", color="lightblue")
g.set(xlim=(0, 80), ylim=(0, None))

# Add labels using loop
for ax in g.axes.flat:
  ax.set_xlabel("age")
  ax.set_ylabel("count")

plt.show()
# gauri
